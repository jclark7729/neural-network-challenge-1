# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
df_y = loans_df["credit_ranking"]

# Display a sample of y
df_y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
dropped_columns = ["credit_ranking"]
df_X = loans_df.drop(columns=dropped_columns)

# Review the features DataFrame
display(df_X.head())
display(df_X.tail())
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
df_X_scaler = scaler.fit(X_train)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_inputs = 11


# Review the number of features
number_inputs
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
nodes_hidden_layer_1 = 6


# Review the number hidden nodes in the first layer
nodes_hidden_layer_1

# Define the number of hidden nodes for the second hidden layer
second_nodes_hidden_layer = 3


# Review the number hidden nodes in the second layer
second_nodes_hidden_layer

# Define the number of neurons in the output layer
neurons_output_layer = 1

# %%
from operator import add
# Create the Sequential model instance
sequential_model = Sequential()

# Add the first hidden layer
sequential_model.add(Dense(units=nodes_hidden_layer_1, input_dim=number_inputs, activation="relu"))

# Add the second hidden layer

sequential_model.add(Dense(units=second_nodes_hidden_layer, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
neurons_output_layer = 1
sequential_model.add(Dense(units=neurons_output_layer, activation="linear"))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Display the Sequential model summary
display(sequential_model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 97 (388.00 B)
#  Trainable params: 97 (388.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
sequential_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
sequential_model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4738 - loss: 8.4817
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4836 - loss: 8.3242
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4742 - loss: 8.4742
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4636 - loss: 8.6463
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4795 - loss: 8.3900
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4656 - loss: 8.6140
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4590 - loss: 8.7198
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4596 - loss: 8.7105
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4781 - loss: 8.4123
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4458 - loss: 8.9321
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4729 - loss: 8.4951
# Epoch 12/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = sequential_model.evaluate(X_test, y_test, verbose=2)

# Display the model loss and accuracy results
display(model_loss)
display(model_accuracy)
# Out:
# 13/13 - 0s - 13ms/step - accuracy: 0.4700 - loss: 8.5426
# 8.542590141296387
# 0.4699999988079071

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
model_path = Path("student_loans.keras")

# Export your model to a keras file
export_model = sequential_model.save(model_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path

model_path = Path("student_loans.keras")

# Load the model to a new object
model_loaded = tf.keras.models.load_model(model_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = model_loaded.predict(X_test)

# Display a sample of the predictions
sample_predictions = predictions[:5]
sample_predictions
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[ -8.402522 ],
#        [-15.557137 ],
#        [ -4.7368846],
#        [-14.13649  ],
#        [ -6.0060105]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
df = pd.DataFrame(sample_predictions)
df = df.round(0)
df
# Out:
#       0
# 0  -8.0
# 1 -16.0
# 2  -5.0
# 3 -14.0
# 4  -6.0

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(predictions, y_test)
# Out:
# [[ -8.402522 ]
#  [-15.557137 ]
#  [ -4.7368846]
#  [-14.13649  ]
#  [ -6.0060105]
#  [ -5.2590585]
#  [ -7.099734 ]
#  [-24.522655 ]
#  [ -4.5771837]
#  [ -3.5605865]
#  [-15.6076355]
#  [ -7.996126 ]
#  [-17.233007 ]
#  [ -4.8537827]
#  [-11.089536 ]
#  [-12.334834 ]
#  [-11.872824 ]
#  [ -4.9663873]
#  [ -4.036179 ]
#  [ -4.2743354]
#  [ -4.3314676]
#  [-11.158178 ]
#  [ -5.475961 ]
#  [ -5.9475136]
#  [-18.782816 ]
#  [-10.499995 ]
#  [ -4.579244 ]
#  [-15.600314 ]
#  [-14.513835 ]
#  [-65.49335  ]
#  [ -5.1753893]
#  [ -5.025009 ]
#  [-20.847048 ]
#  [ -4.0105762]
#  [-24.076561 ]
#  [-18.766388 ]
#  [ -3.6788042]
#  [ -4.1372814]
#  [ -3.0496938]
#  [ -4.979426 ]
#  [ -9.559187 ]
#  [-32.427006 ]
#  [-16.06433  ]
#  [-10.786218 ]
#  [-31.003443 ]
#  [ -4.1604033]
#  [ -9.455129 ]
#  [ -3.5862074]
#  [-14.614893 ]
#  [ -5.579637 ]
#  [-35.00496  ]
#  [ -3.4186373]
#  [ -6.6069007]
#  [-31.200602 ]
#  [ -8.523368 ]
#  [ -5.452483 ]
#  [ -4.735214 ]
#  [ -5.4358783]
# ...

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# The data takes into account the following:
# 1. prior success of the degree granting institution(this helps establish a confidence factor in the student's potential for longterm success)
# 2. location/cost of living of the institution($10k in California is worth a lot less than $10k in Ohio)
# 3. student GPA and payment history(this helps to demonstrate the student's worthiness of investment)
# 4. STEM degree(this helps promote the most needed types of degrees in Science, Tech, Engineering and Math)
#
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# I believe that using context-baseed filtering is the most appropriate for this type of deep learning. The definition of Context-based filtering - it takes into account the situation or context in which the recommendation is being made.
#
#  This model fits the Context filtering for the following reasons: 1. by considering the specific context in which each student is situated, the loan can be tailored to the student's specific circumstances; 2. factors like success rate of the institution and location can greatly influence the potential outcome for the student, which makes the scoring more relevant and accurate; 3. as contextual factors change, like a student's GPA or payment history, the model can make adjustments to the student's score
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Initially, I thought the system should collect gender and minority data to factor into the overall score.  However, the Supreme Court recently ruled that college admissions using minority and gender scores for admission were illegal.  Therefore, my assumption is that these factors should also be excluded from financial calculations for student loans. Removing gender and minority data from the calculation, I do not see any other data that should be considered.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
